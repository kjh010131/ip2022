# %%
tu = (23, 'abc', 4.56, (2,3), 'def')

# %%
li = ["abc", 34, 4.34, 23]

# %%
st = "Hello World"

# %%
st = 'Hello World'

# %%
st = """This is a multi-line
string that uses triple quotes."""

# %%
tu[1]
# Out:
# 'abc'

# %%
li[1]
# Out:
# 34

# %%
st = "Hello World"

# %%
st[1]
# Out:
# 'e'

# %%
t = (23, 'abc', 4.56, (2,3), 'def')

# %%
t[-3]
# Out:
# 4.56

# %%
t[1:4]
# Out:
# ('abc', 4.56, (2, 3))

# %%
t[1:-1]
# Out:
# ('abc', 4.56, (2, 3))

# %%
t[1:-1:2]
# Out:
# ('abc', (2, 3))

# %%
t[:2]
# Out:
# (23, 'abc')

# %%
t[2:]
# Out:
# (4.56, (2, 3), 'def')

# %%
t[:]
# Out:
# (23, 'abc', 4.56, (2, 3), 'def')

# %%
list2 = list1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-bd3a2cfee365> in <module>
# ----> 1 list2 = list1
#
# NameError: name 'list1' is not defined

# %%
list2 = list1[:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-7c66c287cfaf> in <module>
# ----> 1 list2 = list1[:]
#
# NameError: name 'list1' is not defined

# %%
t = [1,2,4,5]

# %%
3 in t
# Out:
# False

# %%
4 in t
# Out:
# True

# %%
4 not in t
# Out:
# False

# %%
a = "abcde"

# %%
'c' in a
# Out:
# True

# %%
'cd' in a
# Out:
# True

# %%
'ac' in a
# Out:
# False

# %%
(1,2,3) + (4,5,6)
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
[1,2,3] + [4,5,6]
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
"Hello" + " " + "World"
# Out:
# 'Hello World'
